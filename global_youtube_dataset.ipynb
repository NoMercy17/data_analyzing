# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_csv("Global YouTube Statistics.csv", encoding='latin1')

df.head(3)
# Out:
#    rank        Youtuber  subscribers     video views          category  \
# 0     1        T-Series    245000000 228000000000.00             Music
# 1     2  YouTube Movies    170000000            0.00  Film & Animation
# 2     3         MrBeast    166000000  28368841870.00     Entertainment
#
#            Title  uploads        Country Abbreviation   channel_type  ...  \
# 0       T-Series    20082          India           IN          Music  ...
# 1  youtubemovies        1  United States           US          Games  ...
# 2        MrBeast      741  United States           US  Entertainment  ...
#
#    subscribers_for_last_30_days  created_year  created_month  created_date  \
# 0                    2000000.00       2006.00            Mar         13.00
# 1                           NaN       2006.00            Mar          5.00
# 2                    8000000.00       2012.00            Feb         20.00
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.isna().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.set_option("display.float_format", "{:.0f}".format)
category_subscribers_mean = df.groupby('category')['subscribers'].mean()
category_subscribers_mean.sort_values(ascending=False, inplace=True)

# %%
category_subscribers_mean.plot(kind = 'bar') # see the categ information
# Out:
# <Axes: xlabel='category'>

# %%
channel_type_counts = df["channel_type"].value_counts()
channel_type_counts
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
channel_type_counts.plot(kind = 'pie')
plt.xlabel('Channel Type Distributino')
# Out:
# Text(0.5, 0, 'Channel Type Distributino')

# %%
plt.scatter(df['subscribers'], df['video views'])

# %%
country_subscribers_total = df.groupby('Country')['subscribers'].sum()              
country_subscribers_total
# Out:
# Country
# Afghanistan               20400000
# Andorra                   15100000
# Argentina                328500000
# Australia                172000000
# Bangladesh                13900000
# Barbados                  41900000
# Brazil                  1221800000
# Canada                   363900000
# Chile                     87200000
# China                     17600000
# Colombia                 264500000
# Cuba                      46300000
# Ecuador                   27700000
# Egypt                     30600000
# El Salvador               46100000
# Finland                   13200000
# France                    83900000
# Germany                  116400000
# India                   4310600000
# Indonesia                534100000
# Iraq                      30200000
# Italy                     39400000
# Japan                    189100000
# Jordan                    67000000
# Kuwait                    30500000
# Latvia                    20200000
# ...

# %%
country_subscribers_total.head(10).plot(kind = 'bar', grid=True)
plt.title('Total Subscribers by Country')
plt.xlabel("Country")
plt.ylabel("Total subscribers")
plt.xticks(rotation = 60)
plt.show()

# %%
# we search for how many subscribers we have in a year
df.groupby('created_year')['subscribers'].mean().sort_values(ascending=True)
# Out:
# created_year
# 2022   13640000
# 2021   18573913
# 2019   18639394
# 2017   18666176
# 2014   20618367
# 2010   20670833
# 2015   21247945
# 2020   21350000
# 2011   21800000
# 2018   23060870
# 2016   23101299
# 2009   23105769
# 2008   23652174
# 2012   24038235
# 2013   24527632
# 2007   24902041
# 2005   25829167
# 2006   31884615
# 1970   36300000
# Name: subscribers, dtype: float64

# %%
# we calc the median video views by channel type
df.groupby('channel_type')['video_views_rank'].median().sort_values(ascending=True)
# Out:
# channel_type
# Animals             136
# Music               385
# Education           538
# News                612
# Entertainment       796
# Film                880
# Comedy             1033
# Sports             1186
# Nonprofit          1538
# Howto              1574
# People             1868
# Games              1944
# Tech               2420
# Autos           3468229
# Name: video_views_rank, dtype: float64

# %%
# the nr of subscribers in the the last 30 months from every country
df.groupby('Country')['subscribers_for_last_30_days'].max().sort_values(ascending=True)
# Out:
# Country
# Samoa                        3
# Cuba                        10
# Afghanistan                 12
# Venezuela                  100
# Egypt                   100000
# France                  100000
# Barbados                100000
# China                   100000
# Switzerland             100000
# Netherlands             200000
# Singapore               200000
# El Salvador             200000
# Malaysia                200000
# Vietnam                 200000
# Ukraine                 230000
# Jordan                  300000
# Ecuador                 300000
# Thailand                300000
# Canada                  400000
# Philippines             500000
# Saudi Arabia            500000
# Chile                   500000
# Mexico                  600000
# Australia               600000
# United Kingdom          600000
# Spain                   800000
# Germany                 900000
# Japan                  1100000
# Brazil                 1100000
# Latvia                 1200000
# ...

# %%
df.groupby('created_month')['subscribers'].sum()
# Out:
# created_month
# Apr    1581200000
# Aug    1813600000
# Dec    1577300000
# Feb    1533800000
# Jan    2254600000
# Jul    1922300000
# Jun    1846400000
# Mar    2320500000
# May    1997700000
# Nov    1930200000
# Oct    1503700000
# Sep    2496200000
# Name: subscribers, dtype: int64

# %%
# total uploads based on channel
df.groupby('channel_type')['uploads'].sum()
# Out:
# channel_type
# Animals            42868
# Autos                949
# Comedy             81722
# Education         146355
# Entertainment    3345035
# Film              114654
# Games             399473
# Howto              79417
# Music             424950
# News             3989151
# Nonprofit         205824
# People            117424
# Sports            158995
# Tech               33780
# Name: uploads, dtype: int64

# %%
df.groupby(['Latitude','Longitude']).size()
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
sns.boxplot(x='channel_type', y = 'highest_monthly_earnings', data=df)
plt.xlabel('channel_type')
plt.ylabel('highest_monthly_earning')
plt.xticks(rotation = 60)
plt.show()

# %%
df.groupby(['category', 'Country'])['subscribers'].sum().unstack().plot(kind = 'bar', stacked=True)
plt.xlabel("category")
plt.ylabel("total subscribers")
plt.xticks(rotation = 90)
plt.legend(title = "Country", bbox_to_anchor =(1, 1), loc = 'upper left')
plt.show()
